# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
white_df = pd.read_csv('/Users/ai-lab07/Downloads/winequality-white.csv', sep=';')
print(white_df.shape)
white_df['is_red'] = 0
white_df = white_df.drop_duplicates(keep='first')
print(white_df.shape)
white_df.head()
# Out:
# (4898, 12)
# (3961, 13)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality  is_red
# 0      8.8        6       0
# 1      9.5        6       0
# 2     10.1        6       0
# 3      9.9        6       0
# 6      9.6        6       0

# %%
red_df = pd.read_csv('/Users/ai-lab07/Downloads/winequality-red.csv', sep=';')
print(red_df.shape)
red_df['is_red'] = 1
red_df = red_df.drop_duplicates(keep='first')
print(red_df.shape)
red_df.head()
# Out:
# (1599, 12)
# (1359, 13)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1
# 2      9.8        5       1
# 3      9.8        6       1
# 5      9.4        5       1

# %%
df = pd.concat([red_df, white_df], ignore_index=True)
print(df.shape)
df.sample(5)
# Out:
# (5320, 13)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 306             9.1             0.795         0.00             2.6      0.096
# 3677            6.7             0.190         0.39             1.0      0.032
# 1330            7.0             0.560         0.13             1.6      0.077
# 4187            7.3             0.230         0.24             0.9      0.031
# 5006            7.3             0.260         0.53            12.7      0.047
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 306                  11.0                  26.0  0.99940  3.35       0.83
# 3677                 14.0                  71.0  0.98912  3.31       0.38
# 1330                 25.0                  42.0  0.99629  3.34       0.59
# 4187                 29.0                  86.0  0.98926  2.90       0.38
# 5006                 60.5                 156.0  0.99840  3.06       0.45
#
#       alcohol  quality  is_red
# 306       9.4        6       1
# 3677     13.0        7       0
# 1330      9.2        5       1
# 4187     12.2        6       0
# 5006      9.1        6       0

# %%
plt.style.use('seaborn')
df['quality'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df = df[(df['quality'] > 4) & (df['quality'] < 8)]
df = df.reset_index(drop=True)

# %%
df['quality'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
train, test = train_test_split(df, test_size=0.2, random_state=1)
train, validation = train_test_split(train, test_size=0.2, random_state=1)

# %%
train_stats = train.describe()
train_stats.pop('is_red')
train_stats.pop('quality')
train_stats = train_stats.T
train_stats
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %%
def format_output(data):
  is_red = data.pop('is_red')
  quality = data.pop('quality')
  is_red = np.array(is_red)
  quality = np.array(quality)
  return is_red, quality

train_y = format_output(train)
valid_y = format_output(validation)
test_y = format_output(test)

# %%
def norm(x):
  return (x-train_stats['mean'])/train_stats['std']

train_x = norm(train)
valid_x = norm(validation)
test_x = norm(test)

# %%
def base_model(inputs):
  x = Dense(units=128, activation='relu', name='Dense_1')(inputs)
  x = Dense(units=128, activation='relu', name='Dense_2')(x)
  return x

def final_model(inputs):
  x = base_model(inputs)
  wine_quality = Dense(units='1', name='wine_quality')(x)
  wine_type = Dense(units='1', activation='sigmoid', name='wine_type')(x)
  model = Model(inputs=inputs, outputs=[wine_type, wine_quality])
  return model

inputs = inputs(shape=(11, ))
model = final_model(inputs)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0f0ebcf96b90> in <module>
#      11   return model
#      12
# ---> 13 inputs = inputs(shape=(11, ))
#      14 model = final_model(inputs)
#      15 model.summary()
#
# NameError: name 'inputs' is not defined
